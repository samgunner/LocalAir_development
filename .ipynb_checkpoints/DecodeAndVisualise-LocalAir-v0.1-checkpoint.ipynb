# %%
from speck import SpeckCipher
import sys
import os

import geopandas as gpd
import pandas as pd
from shapely.geometry import LineString
import json

import numpy as np

import matplotlib.pyplot as plt

pd.options.display.max_columns = None
uploadFormat = True
numOfChunks = 60

# %%
# the name of the directory where the files are stored
# if you have downloaded this off git you will need to change this!
directory_in_str = '/home/lifegarb/Documents/Work/Projects/211025_Voi_scooter_feasiability/data/on_bike/231023'

# before converting to a data frame, all the data is going to go into a list of dicts, this list is called:
data = []

# and this is decode key for the spec incryption
key_string = '{0xad, 0x1c, 0x4b, 0x6, 0x5c, 0x85, 0x2a, 0x48, 0xe4, 0xed, 0x33, 0x23, 0x4c, 0x9f, 0xed, 0x56, 0x23, 0x46, 0x59, 0xfa, 0x3c, 0x70, 0x82, 0x97, 0x45, 0xbd, 0x2b, 0xf1, 0xdc, 0xf4, 0xb6, 0xce}'

# the key string format above is how the teensy needs in, we convert it into an int for python thusly:
# we can convert into somethign this code can use by doing this:
key = [int(i,16) for i in key_string[1:-1].split(',')]

# and now with the key wecan set up our Speck Decryptre
my_speck = SpeckCipher(int.from_bytes(bytes(key), byteorder='big'), key_size=256, block_size=128)

# %%
def ddmm_to_degrees(ddmm):
    degrees, minutes = ddmm.astype('float64').divmod(100)
    return (degrees + minutes/60)

def missing_data(series):
    return series == '-'

# %%
directory = os.fsencode(directory_in_str)

# we are going to iterate through the files
for fileBytes in os.listdir(directory):
    # get the name of the file, to see if it has the correct extention 
    filename = os.fsdecode(fileBytes)
    # and if it does, we process it
    if filename.endswith(".bin"):
        print('Checking {}'.format(filename))
        with open(os.path.join(directory, fileBytes), 'r') as file:
            line_count = 0
            # go through the file line by line
            # check the line isn't blank
            for line in file:
                if line == '\n':
                    continue
                if uploadFormat:
                    # this means that the file is in the funny format that you seem to get when
                    # uploading via Strings from the sensor to James's server. We have to convert 
                    # it into the normal format
                    while True:
                        line_part = file.readline()
                        if (line_part == '\n' or line_part == ''):
                            break
                        line = line.strip() + line_part.strip();
                # we need a line encramter so that we can tell the user where there are errors
                line_count = line_count + 1
                # and this is going to be the string into which we save the decoded ascii
                DecodedAsciiLine = ''

                # each line is encoded into a number of encoded chunks, at the moment that number is 60,
                # although it might change so I've put it in a variable.
                for i in range(numOfChunks):
                    encChunk = line[i*32:(i*32)+32]
                    try:
                        CipherTextChunk = int(encChunk, 16)
                    except ValueError:
                        print("Could not convert to int in {}, line {}, chunk {}, could not decrypt".format(
                            filename,line_count,i), 
                            file=sys.stderr)
                    PlaneTextChunk = hex(my_speck.decrypt(CipherTextChunk))

                    # now decode the hex to ascii

                    # so the message ends with guff, so we have to look out for the nulll byte,
                    # which signifies the end.
                    # convert to a byte array
                    # we cut off the first two characters because they are the '0x' signifing hex
                    try:
                        PlaneByteArray =  bytearray.fromhex(PlaneTextChunk[2:])
                    except ValueError:
                        print("Non-Hex Value found in line {}, chunk {}, could not decrypt".format(
                            filename,line_count,i), 
                            file=sys.stderr)
                        AsciiChunk = ''
                    # look for the null character
                    nullLoc = PlaneByteArray.find(b'\00')

                    # if the location returned is 0 or higher then there is a null character in there
                    # and we must ignore everything after it
                    if (nullLoc > -1):
                        try:
                            AsciiChunk = bytearray.fromhex(PlaneTextChunk[2:])[0:nullLoc].decode()
                        except UnicodeDecodeError:
                            print('Error in {}, line {}, chunk {}, count not convert to ascii'.format(
                                filename, line_count, i), file=sys.stderr)
                            AsciiChunk = ''
                        except ValueError:
                            print("Non-Hex Value found in {}, line {}, chunk {}, could not convert to ascii".format(
                                filename, line_count,i), 
                                file=sys.stderr)
                            AsciiChunk = ''
                    else:
                        try:
                            AsciiChunk = bytearray.fromhex(PlaneTextChunk[2:]).decode()
                        except UnicodeDecodeError:
                            print('Error in {}, line {}, chunk {}, count not convert to ascii'.format(
                                filename, line_count, i), file=sys.stderr)
                            AsciiChunk = ''
                        except ValueError:
                            print("Non-Hex Value found in line {}, chunk {}, could not convert to ascii".format(
                                filename, line_count,i), 
                                file=sys.stderr)
                            AsciiChunk = ''
                    # and concat the new block onto the exisiting string
                    DecodedAsciiLine = DecodedAsciiLine + AsciiChunk

                    # if we found the null character then we have reached the end of the message and can 
                    # break the loop
                    if (nullLoc > -1):
                        break
                # now we are going to try and decode the json string and convert it into a nested data structure
                try:
                    data.append(json.loads(DecodedAsciiLine.strip()))
                except ValueError:
                    # if it doesn't work, then try and output it.
                    print('Error Decoding JSON in {}, on line {}'.format(filename, line_count),
                          file=sys.stderr
                         )
            continue
    else:
        continue
# Out:
# Checking 20231023_180210_8439.bin
# Checking 20231023_180152_9086.bin
# Error Decoding JSON in 20231023_180210_8439.bin, on line 6
# Error Decoding JSON in 20231023_180210_8439.bin, on line 14
# Error Decoding JSON in 20231023_180210_8439.bin, on line 18
# Error Decoding JSON in 20231023_180210_8439.bin, on line 45
# Error Decoding JSON in 20231023_180210_8439.bin, on line 63
# Error Decoding JSON in 20231023_180210_8439.bin, on line 76
# Error Decoding JSON in 20231023_180210_8439.bin, on line 77
# Error Decoding JSON in 20231023_180210_8439.bin, on line 78
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 19, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 20, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 21, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 22, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 23, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 24, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 25, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 26, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 27, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 28, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 29, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 30, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 31, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 32, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 33, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 34, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 35, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 36, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 37, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 38, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 39, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 40, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 41, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 42, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 43, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 44, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 45, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 46, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 47, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 48, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 49, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 50, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 51, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 52, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 53, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 54, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 55, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 56, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 57, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 58, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Could not convert to int in 20231023_180210_8439.bin, line 83, chunk 59, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not decrypt
# Non-Hex Value found in line 20231023_180210_8439.bin, chunk 83, could not convert to ascii
# Error Decoding JSON in 20231023_180210_8439.bin, on line 83
# Error Decoding JSON in 20231023_180152_9086.bin, on line 40
# Error Decoding JSON in 20231023_180152_9086.bin, on line 142
# Error Decoding JSON in 20231023_180152_9086.bin, on line 173
# Error Decoding JSON in 20231023_180152_9086.bin, on line 177
# Error Decoding JSON in 20231023_180152_9086.bin, on line 200
# Error Decoding JSON in 20231023_180152_9086.bin, on line 203
# Error Decoding JSON in 20231023_180152_9086.bin, on line 205
# Error Decoding JSON in 20231023_180152_9086.bin, on line 214
# Error in 20231023_180152_9086.bin, line 220, chunk 10, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 11, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 11, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 12, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 12, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 13, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 13, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 14, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 14, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 15, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 15, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 16, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 16, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 17, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 17, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 18, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 18, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 19, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 19, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 20, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 20, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 21, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 21, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 22, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 22, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 23, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 23, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 24, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 24, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 25, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 25, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 26, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 26, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 27, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 27, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 28, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 28, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 29, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 29, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 30, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 30, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 31, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 31, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 32, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 32, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 33, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 33, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 34, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 34, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 35, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 35, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 36, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 36, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 37, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 37, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 38, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 38, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 39, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 39, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 40, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 40, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 41, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 41, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 42, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 42, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 43, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 43, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 44, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 44, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 45, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 45, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 46, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 46, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 47, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 47, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 48, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 48, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 49, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 49, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 50, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 50, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 51, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 51, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 52, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 52, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 53, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 53, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 54, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 54, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 55, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 55, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 56, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 56, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 57, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 57, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 58, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 58, count not convert to ascii
# Could not convert to int in 20231023_180152_9086.bin, line 220, chunk 59, could not decrypt
# Error in 20231023_180152_9086.bin, line 220, chunk 59, count not convert to ascii
# Error Decoding JSON in 20231023_180152_9086.bin, on line 220
# Error in 20231023_175927_8875.bin, line 1, chunk 34, count not convert to ascii
# Error in 20231023_175927_8875.bin, line 1, chunk 35, count not convert to ascii
# Error in 20231023_175927_8875.bin, line 1, chunk 36, count not convert to ascii
# Error in 20231023_175927_8875.bin, line 1, chunk 37, count not convert to ascii
# Error in 20231023_175927_8875.bin, line 1, chunk 38, count not convert to ascii
# Error in 20231023_175927_8875.bin, line 1, chunk 39, count not convert to ascii
# Error in 20231023_175927_8875.bin, line 1, chunk 40, count not convert to ascii
# Error Decoding JSON in 20231023_175927_8875.bin, on line 19
# Error Decoding JSON in 20231023_175927_8875.bin, on line 22
# Error Decoding JSON in 20231023_175927_8875.bin, on line 27
# Error Decoding JSON in 20231023_175927_8875.bin, on line 36
# Error Decoding JSON in 20231023_175927_8875.bin, on line 49
# Error Decoding JSON in 20231023_175927_8875.bin, on line 56
# Error in 20231023_175927_8875.bin, line 61, chunk 29, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 30, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 30, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 31, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 31, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 32, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 32, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 33, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 33, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 34, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 34, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 35, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 35, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 36, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 36, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 37, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 37, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 38, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 38, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 39, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 39, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 40, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 40, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 41, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 41, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 42, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 42, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 43, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 43, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 44, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 44, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 45, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 45, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 46, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 46, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 47, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 47, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 48, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 48, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 49, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 49, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 50, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 50, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 51, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 51, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 52, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 52, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 53, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 53, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 54, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 54, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 55, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 55, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 56, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 56, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 57, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 57, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 58, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 58, count not convert to ascii
# Could not convert to int in 20231023_175927_8875.bin, line 61, chunk 59, could not decrypt
# Error in 20231023_175927_8875.bin, line 61, chunk 59, count not convert to ascii
# Error Decoding JSON in 20231023_175927_8875.bin, on line 61
# Error Decoding JSON in 20231023_180242_9565.bin, on line 3
# Error Decoding JSON in 20231023_180242_9565.bin, on line 12
# Error Decoding JSON in 20231023_180242_9565.bin, on line 16
# Error Decoding JSON in 20231023_180242_9565.bin, on line 23
# Error Decoding JSON in 20231023_180242_9565.bin, on line 36
# Error Decoding JSON in 20231023_180242_9565.bin, on line 44
# Error Decoding JSON in 20231023_180242_9565.bin, on line 56
# Checking 20231023_175927_8875.bin
# Checking 20231023_180242_9565.bin
# Error Decoding JSON in 20231023_180242_9565.bin, on line 99
# Error Decoding JSON in 20231023_180242_9565.bin, on line 100
# Error Decoding JSON in 20231023_180242_9565.bin, on line 117
# Error Decoding JSON in 20231023_180242_9565.bin, on line 129
# Error Decoding JSON in 20231023_180242_9565.bin, on line 152
# Error Decoding JSON in 20231023_180242_9565.bin, on line 157
# Error Decoding JSON in 20231023_180242_9565.bin, on line 158
# Error Decoding JSON in 20231023_180242_9565.bin, on line 182
# Error Decoding JSON in 20231023_180242_9565.bin, on line 203
# Error Decoding JSON in 20231023_180242_9565.bin, on line 206
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 16, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 17, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 18, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 19, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 20, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 21, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 22, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 23, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 24, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 25, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 26, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 27, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 28, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 29, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 30, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 31, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 32, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 33, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 34, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 35, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 36, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 37, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 38, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 39, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 40, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 41, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 42, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 43, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 44, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 45, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 46, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 47, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 48, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 49, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 50, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 51, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 52, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 53, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 54, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 55, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 56, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 57, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 58, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Could not convert to int in 20231023_180242_9565.bin, line 210, chunk 59, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not decrypt
# Non-Hex Value found in line 20231023_180242_9565.bin, chunk 210, could not convert to ascii
# Error Decoding JSON in 20231023_180242_9565.bin, on line 210
# Error Decoding JSON in 20231023_175911_4184.bin, on line 3
# Error Decoding JSON in 20231023_175911_4184.bin, on line 24
# Checking 20231023_175911_4184.bin
# Error Decoding JSON in 20231023_175911_4184.bin, on line 58
# Error Decoding JSON in 20231023_175911_4184.bin, on line 67
# Error Decoding JSON in 20231023_175911_4184.bin, on line 81
# Error Decoding JSON in 20231023_175911_4184.bin, on line 102
# Error in 20231023_175911_4184.bin, line 108, chunk 36, count not convert to ascii
# Error in 20231023_175911_4184.bin, line 108, chunk 37, count not convert to ascii
# Error in 20231023_175911_4184.bin, line 108, chunk 38, count not convert to ascii
# Error in 20231023_175911_4184.bin, line 108, chunk 39, count not convert to ascii
# Error in 20231023_175911_4184.bin, line 108, chunk 40, count not convert to ascii
# Error Decoding JSON in 20231023_175911_4184.bin, on line 140
# Error Decoding JSON in 20231023_175911_4184.bin, on line 146
# Error Decoding JSON in 20231023_175911_4184.bin, on line 149
# Error Decoding JSON in 20231023_175911_4184.bin, on line 171
# Error Decoding JSON in 20231023_175911_4184.bin, on line 179
# Error Decoding JSON in 20231023_175911_4184.bin, on line 180
# Error Decoding JSON in 20231023_175911_4184.bin, on line 270
# Error Decoding JSON in 20231023_175911_4184.bin, on line 271
# Error Decoding JSON in 20231023_175911_4184.bin, on line 273
# Error Decoding JSON in 20231023_175911_4184.bin, on line 278
# Error Decoding JSON in 20231023_175911_4184.bin, on line 305
# Error Decoding JSON in 20231023_175911_4184.bin, on line 316
# Error Decoding JSON in 20231023_175911_4184.bin, on line 318
# Error Decoding JSON in 20231023_175911_4184.bin, on line 341
# Error Decoding JSON in 20231023_175911_4184.bin, on line 345
# Error in 20231023_175911_4184.bin, line 349, chunk 6, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 7, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 7, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 8, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 8, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 9, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 9, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 10, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 10, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 11, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 11, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 12, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 12, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 13, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 13, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 14, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 14, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 15, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 15, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 16, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 16, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 17, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 17, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 18, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 18, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 19, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 19, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 20, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 20, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 21, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 21, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 22, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 22, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 23, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 23, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 24, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 24, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 25, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 25, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 26, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 26, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 27, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 27, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 28, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 28, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 29, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 29, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 30, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 30, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 31, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 31, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 32, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 32, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 33, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 33, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 34, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 34, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 35, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 35, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 36, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 36, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 37, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 37, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 38, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 38, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 39, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 39, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 40, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 40, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 41, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 41, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 42, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 42, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 43, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 43, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 44, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 44, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 45, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 45, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 46, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 46, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 47, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 47, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 48, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 48, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 49, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 49, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 50, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 50, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 51, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 51, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 52, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 52, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 53, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 53, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 54, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 54, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 55, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 55, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 56, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 56, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 57, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 57, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 58, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 58, count not convert to ascii
# Could not convert to int in 20231023_175911_4184.bin, line 349, chunk 59, could not decrypt
# Error in 20231023_175911_4184.bin, line 349, chunk 59, count not convert to ascii
# Error Decoding JSON in 20231023_175911_4184.bin, on line 349

# %%
df = pd.DataFrame(data)

# putting everything into a single flat df.
# the FFT bins are named after the frequency they capture.

df_flat = pd.concat([pd.to_datetime(df.datetime), 
           pd.json_normalize(df.GPS), 
           pd.json_normalize(df.DHT), 
           pd.json_normalize(df.MultiGas),
           pd.json_normalize(df.PM_Sensor),
           pd.DataFrame(df['FFT'].to_list(),columns = ['FFT.{}Hz'.format(i*43) for i in range(37)])
          ], axis=1)

df_flat = df_flat.mask(missing_data)
#data = data.convert_dtypes()
df_flat = df_flat.dropna()
#df_flat = df_flat.droplevel(level=0, axis=1)

# %%
df_flat
# Out:
#                      datetime   fix speed       angle satellites location.lat  \
# 0   2023-10-23 16:28:38+00:00  True  0.55         151         10  5128.434082
# 1   2023-10-23 16:28:43+00:00  True  0.37  123.349998         10  5128.434082
# 2   2023-10-23 16:28:48+00:00  True  0.37  123.349998         13   5128.43457
# 3   2023-10-23 16:28:53+00:00  True  0.14  255.210007         13   5128.43457
# 4   2023-10-23 16:28:58+00:00  True  0.14  255.210007         12  5128.433594
# ..                        ...   ...   ...         ...        ...          ...
# 853 2023-10-23 11:18:20+00:00  True  0.64   355.23999          9  5129.789063
# 854 2023-10-23 11:18:25+00:00  True  0.64   355.23999         10  5129.788574
# 855 2023-10-23 11:18:35+00:00  True  0.72       62.43          9  5129.789063
# 856 2023-10-23 11:18:40+00:00  True  0.98  299.529999          9  5129.789551
# 857 2023-10-23 11:18:45+00:00  True  0.98  299.529999          8  5129.790039
#
#     location.long location.alt humidity  temp heat_index  no2  c2h5ch  voc  \
# 0      233.809601         23.4       50    24      23.76   63     230   79
# 1      233.808899         23.4     66.2  16.8      16.26   63     236   79
# 2      233.808197         23.4     66.1  16.8      16.26   65     240   81
# 3      233.808106         23.4     66.1  16.8      16.26   67     232   81
# 4      233.808502         23.4       66  16.9      16.37   71     238   82
# ..            ...          ...      ...   ...        ...  ...     ...  ...
# 853    235.480194    90.699997     68.5  16.6       16.1   57     187  101
# 854    235.479797    90.800003     68.6  16.6      16.11   56     187  100
# 855    235.479401    91.099998     68.7  16.6      16.11   56     188  100
# 856    235.480392    91.099998     68.7  16.6      16.11   56     188  100
# 857    235.480804    91.300003     68.7  16.6      16.11   56     188   99
#
#      co  atmos_enviro.AE_1.0  atmos_enviro.AE_2.5  atmos_enviro.AE_10.0  \
# 0    74                    2                    3                     4
# 1    78                    2                    3                     4
# 2    80                    2                    3                     4
# 3    74                    2                    3                     5
# 4    78                    2                    4                     5
# ..   ..                  ...                  ...                   ...
# 853  68                    2                    3                     5
# 854  68                    2                    3                     4
# 855  68                    2                    3                     5
# 856  69                    2                    3                     4
# 857  68                    2                    4                     4
#
#      FFT.0Hz  FFT.43Hz  FFT.86Hz  FFT.129Hz  FFT.172Hz  FFT.215Hz  FFT.258Hz  \
# 0       2.14      6.53      4.09       4.27       8.36       7.75       7.02
# 1       0.18      6.04     10.19       9.28      11.17       6.71       5.55
# 2       1.95     13.67     13.85       6.53       5.25       4.52       3.05
# 3       5.68      6.23      2.87       1.71       2.38       5.55       9.52
# 4       1.53      2.62      2.81       5.98       4.76       1.89       6.77
# ..       ...       ...       ...        ...        ...        ...        ...
# 853     6.90      6.90     10.07       9.03       2.44       3.85       3.42
# 854     2.32      1.65      3.91       2.44       3.48       5.25       4.27
# 855     1.53      2.20      4.82       2.69       6.04       3.85       1.46
# 856     9.03      6.71     10.07       8.48       2.50       2.01       1.59
# 857     6.41      1.53      6.10       3.42       4.03       3.66       4.64
#
#      FFT.301Hz  FFT.344Hz  FFT.387Hz  FFT.430Hz  FFT.473Hz  FFT.516Hz  \
# 0        10.99      10.68       5.00       1.53       1.77       1.65
# 1         7.02       2.75       3.36       1.22       1.04       0.55
# 2         4.03       4.70       1.89       0.85       0.85       0.92
# 3        10.07      11.66       6.71       1.95       0.55       1.04
# 4        12.15       6.16       1.28       0.67       0.67       0.24
# ..         ...        ...        ...        ...        ...        ...
# 853       5.86       5.13       1.16       0.55       0.67       0.92
# 854       6.65       5.37       3.11       3.17       0.85       0.49
# 855       1.71       3.23       1.95       0.31       1.22       1.16
# 856       1.10       2.93       3.97      10.86       9.77       2.32
# 857       9.64       8.12       3.11       1.59       1.16       0.98
#
#      FFT.559Hz  FFT.602Hz  FFT.645Hz  FFT.688Hz  FFT.731Hz  FFT.774Hz  \
# 0         2.32       2.87       3.48       2.08       1.77       0.24
# 1         1.65       3.72       4.33       1.59       0.73       0.85
# 2         1.22       3.05       2.44       1.22       1.46       0.61
# 3         0.73       3.23       3.36       0.31       1.34       0.18
# 4         1.04       2.32       3.66       0.06       1.28       0.98
# ..         ...        ...        ...        ...        ...        ...
# 853       0.49       2.69       3.78       2.01       0.24       0.12
# 854       1.16       2.62       4.46       2.50       1.16       0.55
# 855       1.59       3.36       3.97       2.08       0.43       0.67
# 856       0.49       2.14       3.91       0.98       0.79       0.43
# 857       1.28       2.99       3.85       1.10       0.98       0.73
#
#      FFT.817Hz  FFT.860Hz  FFT.903Hz  FFT.946Hz  FFT.989Hz  FFT.1032Hz  \
# 0         0.98       1.04       1.65       2.38       1.28        0.18
# 1         1.46       1.04       1.95       2.20       0.61        1.10
# 2         0.92       1.40       1.71       2.08       0.24        0.98
# 3         0.79       0.67       0.73       1.89       1.71        0.92
# 4         0.67       1.65       2.14       1.89       0.98        0.61
# ..         ...        ...        ...        ...        ...         ...
# 853       0.43       1.04       1.16       1.46       1.10        1.46
# 854       0.92       0.73       0.61       0.49       0.49        0.24
# 855       0.98       0.61       0.49       2.14       0.73        0.98
# 856       1.46       1.65       0.61       2.50       1.65        1.10
# 857       0.43       0.43       0.06       1.89       1.04        0.55
#
#      FFT.1075Hz  FFT.1118Hz  FFT.1161Hz  FFT.1204Hz  FFT.1247Hz  FFT.1290Hz  \
# 0          0.43        0.85        1.59        1.28        2.44        1.53
# 1          1.04        0.24        0.12        0.06        0.31        0.00
# 2          0.24        0.43        0.24        0.37        0.79        0.12
# 3          1.40        1.34        0.85        0.37        0.49        0.18
# 4          0.85        0.31        0.24        1.04        0.92        0.37
# ..          ...         ...         ...         ...         ...         ...
# 853        0.61        0.31        0.43        0.43        0.67        0.92
# 854        0.18        0.49        0.18        0.55        0.31        0.43
# 855        1.22        0.12        0.49        0.98        0.43        0.24
# 856        0.73        0.55        0.37        0.55        0.79        0.61
# 857        0.06        0.49        0.61        1.10        0.85        0.79
#
#      FFT.1333Hz  FFT.1376Hz  FFT.1419Hz  FFT.1462Hz  FFT.1505Hz  FFT.1548Hz
# 0          1.40        1.34        0.12        1.59        0.98        0.73
# 1          0.43        0.55        1.04        0.49        1.28        0.55
# 2          0.67        0.43        0.37        0.55        0.49        0.24
# 3          0.67        1.16        1.40        0.92        1.59        1.28
# 4          0.92        0.67        0.55        0.43        0.92        0.79
# ..          ...         ...         ...         ...         ...         ...
# 853        1.46        0.79        0.79        0.79        0.55        0.49
# 854        0.73        0.92        0.79        0.85        0.31        0.37
# 855        0.67        0.67        1.22        1.46        1.10        0.12
# 856        0.67        0.37        0.43        0.06        0.31        0.37
# 857        0.67        0.31        0.37        0.24        0.31        0.18
#
# [853 rows x 55 columns]

# %%
df_flat = gpd.GeoDataFrame(
    df_flat, 
    # geometry=gpd.points_from_xy(data['GPS']['location.long'].pipe(ddmm_to_degrees), 
    #                             data['GPS']['location.lat'].pipe(ddmm_to_degrees), 
    geometry=gpd.points_from_xy(-df_flat['location.long'].pipe(ddmm_to_degrees), 
                                df_flat['location.lat'].pipe(ddmm_to_degrees), 
                                crs='epsg:4326')
)

# %%
df_flat[['satellites',
      'atmos_enviro.AE_1.0',
      'atmos_enviro.AE_2.5',
      'atmos_enviro.AE_10.0', 
      'no2', 
      'co',
      'temp', 
      'geometry']].explore('no2', 
                           cmap='RdYlGn_r',
                           tiles='CartoDB positron', 
                           vmax=200,
                           style_kwds={"style_function":lambda x: {"radius": (10 - x['properties']['satellites'])*2
                                                                  }
                                                                  
                                      }
                           )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d14f18bc1beba88939b5590c2e99f646 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d14f18bc1beba88939b5590c2e99f646&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d14f18bc1beba88939b5590c2e99f646 = L.map(
#                 &quot;map_d14f18bc1beba88939b5590c2e99f646&quot;,
#                 {
#                     center: [51.477657058333335, -2.5648258208333337],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d14f18bc1beba88939b5590c2e99f646);
#
#
#
#
#
#             var tile_layer_9e4fdfcc330d9b112283b21320b4dbbc = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d14f18bc1beba88939b5590c2e99f646);
#
#
#             map_d14f18bc1beba88939b5590c2e99f646.fitBounds(
#                 [[51.458227533333336, -2.5916483566666666], [51.49708658333334, -2.5380032850000003]],
#                 {}
#             );
#
#
#         function geo_json_06d0fd816934e61e52bceb8ed218a4a2_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;305&quot;: case &quot;319&quot;: case &quot;842&quot;:
#                     return {&quot;color&quot;: &quot;#70c164&quot;, &quot;fillColor&quot;: &quot;#70c164&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 0, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;776&quot;: case &quot;811&quot;: case &quot;813&quot;:
#                     return {&quot;color&quot;: &quot;#78c565&quot;, &quot;fillColor&quot;: &quot;#78c565&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: -6, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#7fc866&quot;, &quot;fillColor&quot;: &quot;#7fc866&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: -6, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;816&quot;:
#                     return {&quot;color&quot;: &quot;#8ecf67&quot;, &quot;fillColor&quot;: &quot;#8ecf67&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: -4, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#b5df74&quot;, &quot;fillColor&quot;: &quot;#b5df74&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: -4, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;712&quot;:
#                     return {&quot;color&quot;: &quot;#a9da6c&quot;, &quot;fillColor&quot;: &quot;#a9da6c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: -2, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;680&quot;:
#                     return {&quot;color&quot;: &quot;#bbe278&quot;, &quot;fillColor&quot;: &quot;#bbe278&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: -2, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;675&quot;:
#                     return {&quot;color&quot;: &quot;#bbe278&quot;, &quot;fillColor&quot;: &quot;#bbe278&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 0, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#c7e77f&quot;, &quot;fillColor&quot;: &quot;#c7e77f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 0, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#c5e67e&quot;, &quot;fillColor&quot;: &quot;#c5e67e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 0, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#d3ec87&quot;, &quot;fillColor&quot;: &quot;#d3ec87&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 0, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#d3ec87&quot;, &quot;fillColor&quot;: &quot;#d3ec87&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: -4, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return

# %%
df_flat[['satellites',
      'atmos_enviro.AE_1.0',
      'atmos_enviro.AE_2.5',
      'atmos_enviro.AE_10.0', 
      'no2', 
      'co',
      'temp', 
      'geometry']].explore('co', 
                           cmap='RdYlGn_r',
                           tiles='CartoDB positron', 
                           vmax=100,
                           style_kwds={"style_function":lambda x: {"radius": 5
                                                                  }
                                                                  
                                      }
                           )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91a95788a1f7c749c8903518f2534cf4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91a95788a1f7c749c8903518f2534cf4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91a95788a1f7c749c8903518f2534cf4 = L.map(
#                 &quot;map_91a95788a1f7c749c8903518f2534cf4&quot;,
#                 {
#                     center: [51.477657058333335, -2.5648258208333337],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_91a95788a1f7c749c8903518f2534cf4);
#
#
#
#
#
#             var tile_layer_4aeeed3e956dfc43b55efa2f3a5be6bd = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_91a95788a1f7c749c8903518f2534cf4);
#
#
#             map_91a95788a1f7c749c8903518f2534cf4.fitBounds(
#                 [[51.458227533333336, -2.5916483566666666], [51.49708658333334, -2.5380032850000003]],
#                 {}
#             );
#
#
#         function geo_json_71366be3675c58944604822ab0d44b65_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;3&quot;: case &quot;12&quot;: case &quot;33&quot;: case &quot;39&quot;: case &quot;42&quot;: case &quot;70&quot;: case &quot;139&quot;: case &quot;201&quot;: case &quot;203&quot;: case &quot;208&quot;: case &quot;228&quot;: case &quot;236&quot;: case &quot;255&quot;: case &quot;261&quot;: case &quot;268&quot;: case &quot;280&quot;: case &quot;282&quot;: case &quot;283&quot;: case &quot;341&quot;: case &quot;344&quot;: case &quot;345&quot;: case &quot;351&quot;: case &quot;356&quot;: case &quot;373&quot;: case &quot;376&quot;: case &quot;499&quot;: case &quot;560&quot;: case &quot;562&quot;: case &quot;564&quot;: case &quot;581&quot;: case &quot;582&quot;: case &quot;631&quot;: case &quot;656&quot;: case &quot;691&quot;: case &quot;694&quot;: case &quot;695&quot;: case &quot;696&quot;:
#                     return {&quot;color&quot;: &quot;#c7e77f&quot;, &quot;fillColor&quot;: &quot;#c7e77f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;4&quot;: case &quot;29&quot;: case &quot;37&quot;: case &quot;73&quot;: case &quot;146&quot;: case &quot;147&quot;: case &quot;197&quot;: case &quot;545&quot;: case &quot;546&quot;: case &quot;549&quot;: case &quot;553&quot;: case &quot;556&quot;: case &quot;632&quot;:
#                     return {&quot;color&quot;: &quot;#f1f9ac&quot;, &quot;fillColor&quot;: &quot;#f1f9ac&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;7&quot;: case &quot;17&quot;: case &quot;72&quot;: case &quot;112&quot;: case &quot;454&quot;: case &quot;548&quot;: case &quot;557&quot;: case &quot;780&quot;:
#                     return {&quot;color&quot;: &quot;#fffbb8&quot;, &quot;fillColor&quot;: &quot;#fffbb8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;6&quot;: case &quot;10&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;32&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;43&quot;: case &quot;65&quot;: case &quot;131&quot;: case &quot;176&quot;: case &quot;200&quot;: case &quot;210&quot;: case &quot;233&quot;: case &quot;239&quot;: case &quot;240&quot;: case &quot;254&quot;: case &quot;256&quot;: case &quot;263&quot;: case &quot;272&quot;: case &quot;273&quot;: case &quot;274&quot;: case &quot;342&quot;: case &quot;348&quot;: case &quot;374&quot;: case &quot;379&quot;: case &quot;380&quot;: case &quot;451&quot;: case &quot;662&quot;: case &quot;668&quot;: case &quot;730&quot;: case &quot;733&quot;:
#                     return {&quot;color&quot;: &quot;#d3ec87&quot;, &quot;fillColor&quot;: &quot;#d3ec87&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;13&quot;: case &quot;28&quot;: case &quot;38&quot;: case &quot;40&quot;: case &quot;155&quot;: case &quot;174&quot;: case &quot;175&quot;: case

# %%
plt.scatter(x=df_flat['speed'], y=df_flat['no2'])

# %%
plt.plot(df_flat['datetime'],df_flat['no2'],'o')

# %%
df_flat.datetime
# Out:
# 0     2023-10-23 16:28:38+00:00
# 1     2023-10-23 16:28:43+00:00
# 2     2023-10-23 16:28:48+00:00
# 3     2023-10-23 16:28:53+00:00
# 4     2023-10-23 16:28:58+00:00
#                  ...
# 853   2023-10-23 11:18:20+00:00
# 854   2023-10-23 11:18:25+00:00
# 855   2023-10-23 11:18:35+00:00
# 856   2023-10-23 11:18:40+00:00
# 857   2023-10-23 11:18:45+00:00
# Name: datetime, Length: 853, dtype: datetime64[ns, UTC]

# %%
bins = df_flat.filter(like='FFT').columns

plt.pcolor(df_flat.filter(like='FFT').T)
plt.yticks(np.arange(0.5, bins.size, 1), bins)
plt.xticks(np.arange(0.5, len(df_flat.index), 1), df_flat.datetime)
plt.show()

# %%
plt.plot(df_flat.co)
plt.show()
